# %% [markdown]
# # INDEX
# [1. TRANSFER LEARNING](#TRANSFER-LEARNING "Goto TRANSFER-LEARNING")<br>
# [2. TRAINING FROM SCRATCH](#TRAINING-FROM-SCRATCH "Goto TRAINING FROM SCRATCH")

# %%
# import training libraries
from math import ceil

from keras import backend as K
from keras.models import load_model
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger

from models.keras_ssd300 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.object_detection_2d_patch_sampling_ops import RandomMaxCropFixedAR
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # TRANSFER LEARNING
# [INDEX](#INDEX "Goto INDEX")
# ## Training from pretrained weights
# Pretrained Weights- Trained on COCO data<Br>
# New Training- Training for PASCAL VOC 2007 data

# %% [markdown]
# ## 1. Modify model weights structure of classification layers for training on new objects and save

# %%
import h5py
import numpy as np
import shutil

from misc_utils.tensor_sampling_utils import sample_tensors

# %%
# load weights of the pretrained model
weights_path = 'pretrained_weights/VGG_coco_SSD_300x300_iter_400000_custom.h5'
weights_to_be_trained = h5py.File(weights_path, mode='r+')

# %%
# classifier layer names in the model, first 3 have same number while other 3 have same number
classifier_names1 = ['conv4_3_norm_mbox_conf',
                    'conv8_2_mbox_conf',
                    'conv9_2_mbox_conf']

classifier_names2 = ['fc7_mbox_conf',
                    'conv6_2_mbox_conf',
                    'conv7_2_mbox_conf']

# %%
# check current shape of one of the classifier layers
conv4_3_norm_mbox_conf_kernel = weights_to_be_trained[classifier_names1[0]][classifier_names1[0]]['kernel:0']
conv4_3_norm_mbox_conf_bias = weights_to_be_trained[classifier_names1[0]][classifier_names1[0]]['bias:0']
# 20 classes in the voc dataset with 1 background class
# 4 boxes for each class and hence 21*4 = 84 predictions
conv4_3_norm_mbox_conf_kernel, conv4_3_norm_mbox_conf_bias
# Out:
# (<HDF5 dataset "kernel:0": shape (3, 3, 512, 84), type "<f8">,
#  <HDF5 dataset "bias:0": shape (84,), type "<f8">)

# %%
# TODO: Modify the n_classes number as per the new object detection model to be trained
# Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
n_classes = 20 # set new number of classes to train on

for name in classifier_names1:
    # Get the trained weights for this layer from the source HDF5 weights file.
    kernel = weights_to_be_trained[name][name]['kernel:0'].value
    bias = weights_to_be_trained[name][name]['bias:0'].value

    # Get the shape of the kernel. We're interested in sub-sampling
    height, width, in_channels, out_channels = kernel.shape
    
    # Sub-sample the kernel and bias.
    new_kernel, new_bias = sample_tensors(weights_list=[kernel, bias],
                                          sampling_instructions=[height, width, in_channels, (n_classes+1)*4],
                                          axes=[[3]], # The one bias dimension corresponds to the last kernel dimension.
                                          init=['gaussian', 'zeros'],
                                          mean=0.0,
                                          stddev=0.005)
    
    # Delete the old weights from the destination file.
    del weights_to_be_trained[name][name]['kernel:0']
    del weights_to_be_trained[name][name]['bias:0']
    # Create new datasets for the sub-sampled weights.
    weights_to_be_trained[name][name].create_dataset(name='kernel:0', data=new_kernel)
    weights_to_be_trained[name][name].create_dataset(name='bias:0', data=new_bias)

for name in classifier_names2:
    # Get the trained weights for this layer from the source HDF5 weights file.
    kernel = weights_to_be_trained[name][name]['kernel:0'].value
    bias = weights_to_be_trained[name][name]['bias:0'].value

    # Get the shape of the kernel. We're interested in sub-sampling
    height, width, in_channels, out_channels = kernel.shape
    
    # Sub-sample the kernel and bias.
    new_kernel, new_bias = sample_tensors(weights_list=[kernel, bias],
                                          sampling_instructions=[height, width, in_channels, (n_classes+1)*6],
                                          axes=[[3]], # The one bias dimension corresponds to the last kernel dimension.
                                          init=['gaussian', 'zeros'],
                                          mean=0.0,
                                          stddev=0.005)
    
    # Delete the old weights from the destination file.
    del weights_to_be_trained[name][name]['kernel:0']
    del weights_to_be_trained[name][name]['bias:0']
    # Create new datasets for the sub-sampled weights.
    weights_to_be_trained[name][name].create_dataset(name='kernel:0', data=new_kernel)
    weights_to_be_trained[name][name].create_dataset(name='bias:0', data=new_bias)

# Make sure all data is written to our output file before this sub-routine exits.
weights_to_be_trained.flush()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.

# %% [markdown]
# ## 2. Set the model configuration parameters

# %%
# set model parameters
img_height = 300 # Height of the input images
img_width = 300 # Width of the input images
img_channels = 3 # Number of color channels of the input images
mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. 
n_classes = 20 # set new number of classes to train on
# Do not change this value if you're using any of the pre-trained weights.
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we should set this to `True`, but weirdly the results are better without swapping.
scales = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets.
# scales = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets.
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not you want to limit the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are scaled as in the original implementation
normalize_coords = True

# %% [markdown]
# ## 3. Build the model using modified pretrained weights above

# %%
# 1: Build the Keras model.
K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# 2: Load pretrained weights
model.load_weights(weights_path, by_name=True)

# 3: Instantiate an Adam optimizer and the SSD loss function and compile the model.
adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/ssd/keras_loss_function/keras_ssd_loss.py:95: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/ssd/keras_loss_function/keras_ssd_loss.py:133: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/ssd/keras_loss_function/keras_ssd_loss.py:74: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/ssd/keras_loss_function/keras_ssd_loss.py:166: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %% [markdown]
# ### use repo https://github.com/tzutalin/labelImg to download labelImg software and generate custom dataset for training

# %% [markdown]
# ## 4. Set up the data generators for the training

# %%
# data generation

# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.
# If you have enough memory, consider loading the images into memory
train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets. This can take a while.
# The directories that contain the images.
train_images_dir      = 'train/JPEGImages/'
val_images_dir      = 'val/JPEGImages/'

# The directories that contain the annotations.
train_annotations_dir      = 'train/Annotations/'
val_annotations_dir      = 'val/Annotations/'

# The directories that contain the imageset
train_image_set_filename = 'train/ImageSets/Main/trainval.txt'
val_image_set_filename   = 'val/ImageSets/Main/test.txt'

# The XML parser needs to now what object class names to look for and in which order to map them to integers.
classes = ['background',
           'aeroplane', 'bicycle', 'bird', 'boat',
           'bottle', 'bus', 'car', 'cat',
           'chair', 'cow', 'diningtable', 'dog',
           'horse', 'motorbike', 'person', 'pottedplant',
           'sheep', 'sofa', 'train', 'tvmonitor']

train_dataset.parse_xml(images_dirs=[train_images_dir],
                        image_set_filenames=[train_image_set_filename],
                        annotations_dirs=[train_annotations_dir],
                        classes=classes,
                        include_classes='all',
                        exclude_truncated=False,
                        exclude_difficult=False,
                        ret=False)

val_dataset.parse_xml(images_dirs=[val_images_dir],
                      image_set_filenames=[val_image_set_filename],
                      annotations_dirs=[val_annotations_dir],
                      classes=classes,
                      include_classes='all',
                      exclude_truncated=False,
                      exclude_difficult=True,
                      ret=False)

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

'''train_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07+12_trainval.h5',
                                  resize=False,
                                  variable_image_size=True,
                                  verbose=True)

val_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07_test.h5',
                                resize=False,
                                variable_image_size=True,
                                verbose=True)'''
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing image set 'test.txt':  99%|█████████▉| 4908/4952 [57:27<00:29,  1.49it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4909/4952 [57:28<00:29,  1.45it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4910/4952 [57:29<00:36,  1.15it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4911/4952 [57:30<00:32,  1.27it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4912/4952 [57:30<00:27,  1.43it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4913/4952 [57:31<00:25,  1.54it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4914/4952 [57:31<00:22,  1.66it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4915/4952 [57:32<00:22,  1.67it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4916/4952 [57:33<00:23,  1.55it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4917/4952 [57:34<00:30,  1.14it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4918/4952 [57:35<00:26,  1.29it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4919/4952 [57:35<00:25,  1.30it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4920/4952 [57:36<00:23,  1.37it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4921/4952 [57:37<00:22,  1.36it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4922/4952 [57:38<00:23,  1.28it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4923/4952 [57:38<00:20,  1.44it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4924/4952 [57:39<00:18,  1.54it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4925/4952 [57:39<00:17,  1.58it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4926/4952 [57:41<00:21,  1.19it/s]
# Processing image set 'test.txt':  99%|█████████▉| 4927/4952 [57:41<00:21,  1.18it/s]
# Processing image set 'test.txt': 100%|█████████▉| 4928/4952 [57:42<00:18,  1.31it/s]
# Processing image set 'test.txt': 100%|█████████▉| 4929/4952 [57:43<00:16,  1.39it/s]
# Processing image set 'test.txt': 100%|█████████▉| 4930/4952 [57:44<00:17,  1.28it/s]
# Processing image set 'test.txt': 100%|█████████▉| 
# Loading images into memory:   1%|          | 26/4952 [00:18<57:14,  1.43it/s]
# Loading images into memory:   1%|          | 27/4952 [00:18<53:40,  1.53it/s]
# Loading images into memory:   1%|          | 28/4952 [00:19<51:57,  1.58it/s]
# Loading images into memory:   1%|          | 29/4952 [00:20<1:00:36,  1.35it/s]
# Loading images into memory:   1%|          | 30/4952 [00:20<1:00:58,  1.35it/s]
# Loading images into memory:   1%|          | 31/4952 [00:21<59:15,  1.38it/s]
# Loading images into memory:   1%|          | 32/4952 [00:22<56:33,  1.45it/s]
# Loading images into memory:   1%|          | 33/4952 [00:22<52:12,  1.57it/s]
# Loading images into memory:   1%|          | 34/4952 [00:23<49:31,  1.65it/s]
# Loading images into memory:   1%|          | 35/4952 [00:23<49:18,  1.66it/s]
# Loading images into memory:   1%|          | 36/4952 [00:24<51:33,  1.59it/s]
# Loading images into memory:   1%|          | 37/4952 [00:25<49:59,  1.64it/s]
# Loading images into memory:   1%|          | 38/4952 [00:25<55:14,  1.48it/s]
# Loading images into memory:   1%|          | 39/4952 [00:26<51:48,  1.58it/s]
# Loading images into memory:   1%|          | 40/4952 [00:27<50:22,  1.62it/s]
# Loading images into memory:   1%|          | 41/4952 [00:27<51:21,  1.59it/s]
# Loading images into memory:   1%|          | 42/4952 [00:28<51:07,  1.60it/s]
# Loading images into memory:   1%|          | 43/4952 [00:28<49:18,  1.66it/s]
# Loading images into memory:   1%|          | 44/4952 [00:29<49:11,  1.66it/s]
# Loading images into memory:   1%|          | 45/4952 [00:30<58:23,  1.40it/s]
# Loading images into memory:   1%|          | 46/4952 [00:31<55:23,  1.48it/s]
# Loading images into memory:   1%|          | 47/4952 [00:31<57:34,  1.42it/s]
# Loading images into memory:   1%|          | 48/4952 [00:32<1:04:59,  1.26it/s]
# Loading images into memory:   1%|          | 49/4952 [00:33<58:28,  1.40it/s]
# Loading images into memory:   1%|          | 50/4952 [00:33<53:10,  1.54it/s]
# Loading images into memory:   1%|          | 51/4952 [00:34<55:38,  1.47it/s]
# Loading images into memory:   1%|          | 52/4952 [00:35<1:03:06,  1.29it/s]
# Loading images into memory:   1%|          | 53/4952 [00:36<1:15:16,  1.08it/s]
# Loading images into memory:   1%|          | 54/4952 [00:37<1:05:49,  1.24it/s]
# Loading images into memory:   1%|          | 55/4952 [00:37<59:35,  1.37it/s]
# Loading images into memory:   1%|          | 56/4952 [00:38<53:15,  1.53it/s]
# Loading images into memory:   1%|          | 57/4952 [00:38<49:15,  1.66it/s]
# Loading images into memory:   1%|          | 58/4952 [00:39<47:13,  1.73it/s]
# Loading images into memory:   1%|          | 59/4952 [00:39<45:06,  1.81it/s]
# Loading images into memory:   1%|          | 60/4952 [00:40<45:09,  1.81it/s]
# Loading images into memory:   1%|          | 61/4952 [00:41<45:06,  1.81it/s]
# Loading images into memory:   1%|▏         | 62/4952 [00:41<44:21,  1.84it/s]
# Loading images into memory:   1%|▏         | 63/4952 [00:42<46:57,  1.74it/s]
# Loading images into memory:   1%|▏         | 64/4952 [00:42<46:33,  1.75it/s]
# Loading images into memory:   1%|▏         | 65/4952 [00:43<48:15,  1.69it/s]
# Loading images into memory:   1%|▏         | 66/4952 [00:43<46:16,  1.76it/s]
# Loading images into memory:   1%|▏         | 67/4952 [00:44<55:46,  1.46it/s]
# Loading images into memory:   1%|▏         | 68/4952 [00:45<1:05:46,  1.24it/s]
# Loading images into memory:   1%|▏         | 69/4952 [00:46<1:04:12,  1.27it/s]
# Loading images into memory:   1%|▏         | 70/4952 [00:47<1:02:49,  1.30it/s]
# Loading images into memory:   1%|▏         | 71/4952 [00:48<1:05:32,  1.24it/s]
# Loading images into memory:   1%|▏         | 72/4952 [00:49<1:09:26,  1.17it/s]
# Loading images into memory:   1%|▏         | 73/4952 [00:49<1:00:47,  1.34it/s]
# Loading images into memory:   1%|▏         | 74/4952 [00:50<58:22,  1.39it/s]
# Loading images into memory:   2%|▏         | 75/4952 [00:51<55:54,  1.45it/s]
# Loading images into memory:   2%|▏         | 76/4952 [00:51<52:51,  1.54it/s]
# Loading images into memory:   2%|▏         | 77/4952 [00:52<52:08,  1.56it/s]
# Loading images into memory:   2%|▏         | 78/4952 [00:52<54:09,  1.50it/s]
# Loading images into memory:   2%|▏         | 79/4952 [00:53<52:48,  1.54it/s]
# Loading images into memory:   2%|▏         | 80/4952 [00:54<50:33,  1.61it/s]
# Loading images into memory:   2%|▏         | 81/4952 [00:54<49:27,  1.64it/s]
# Loading images into memory:   2%|▏         | 82/4952 [00:55<46:56,  1.73it/s]
# Loading images into memory:   2%|▏         | 83/4952 [00:57<1:18:31,  1.03it/s]
# Loading images into memory:   2%|▏         | 84/4952 [00:57<1:12:04,  1.13it/s]
# Loading images into memory:   2%|▏         | 85/4952 [00:58<1:02:28,  1.30it/s]
# Loading images into memory:   2%|▏         | 86/4952 [00:58<55:30,  1.46it/s]
# Loading images into memory:   2%|▏         | 87/4952 [00:59<53:41,  1.51it/s]
# Loading images into memory:   2%|▏         | 88/4952 [01:00<56:04,  1.45it/s]
# Loading images into memory:   2%|▏         | 89/4952 [01:00<55:27,  1.46it/s]
# Loading images into memory:   2%|▏         | 90/4952 [01:01<55:07,  1.47it/s]
# Loading images into memory:   2%|▏         | 91/4952 [01:02<56:10,  1.44it/s]
# Loading images into memory:   2%|▏         | 92/4952 [01:02<52:59,  1.53it/s]
# Loading images into memory:   2%|▏         | 93/4952 [01:03<57:25,  1.41it/s]
# Loading images into memory:   2%|▏         | 94/4952 [01:04<53:46,  1.51it/s]
# Loading images into memory:   2%|▏         | 95/4952 [01:05<1:05:01,  1.25it/s]
# Loading images into memory:   2%|▏         | 96/4952 [01:05<1:01:07,  1.32it/s]
# Loading images into memory:   2%|▏         | 97/4952 [01:06<55:07,  1.47it/s]
# Loading images into memory:   2%|▏         | 98/4952 [01:07<52:50,  1.53it/s]
# Loading images into memory:   2%|▏         | 99/4952 [01:07<54:06,  1.49it/s]
# Loading images into memory:   2%|▏         | 100/4952 [01:08<51:19,  1.58it/s]
# Loading images into memory:   4%|▎         | 176/4952 [02:00<48:51,  1.63it/s]
# Loading images into memory:   4%|▎         | 177/4952 [02:00<49:43,  1.60it/s]
# Loading images into memory:   4%|▎         | 178/4952 [02:01<47:55,  1.66it/s]
# Loading images into memory:   4%|▎         | 179/4952 [02:01<47:06,  1.69it/s]
# Loading images into memory:   4%|▎         | 180/4952 [02:02<45:54,  1.73it/s]
# Loading images into memory:   4%|▎         | 181/4952 [02:03<44:17,  1.79it/s]
# Loading images into memory:   4%|▎         | 182/4952 [02:03<47:09,  1.69it/s]
# Loading images into memory:   4%|▎         | 183/4952 [02:04<56:23,  1.41it/s]
# Loading images into memory:   4%|▎         | 184/4952 [02:05<51:39,  1.54it/s]
# Loading images into memory:   4%|▎         | 185/4952 [02:05<48:16,  1.65it/s]
# Loading images into memory:   4%|▍         | 186/4952 [02:06<47:30,  1.67it/s]
# Loading images into memory:   4%|▍         | 187/4952 [02:06<45:30,  1.74it/s]
# Loading images into memory:   4%|▍         | 188/4952 [02:07<51:18,  1.55it/s]
# Loading images into memory:   4%|▍         | 189/4952 [02:08<52:51,  1.50it/s]
# Loading images into memory:   4%|▍         | 190/4952 [02:09<54:39,  1.45it/s]
# Loading images into memory:   4%|▍         | 191/4952 [02:09<55:17,  1.44it/s]
# Loading images into memory:   4%|▍         | 192/4952 [02:10<58:14,  1.36it/s]
# Loading images into memory:   4%|▍         | 193/4952 [02:11<58:22,  1.36it/s]
# Loading images into memory:   4%|▍         | 194/4952 [02:11<55:26,  1.43it/s]
# Loading images into memory:   4%|▍         | 195/4952 [02:12<51:30,  1.54it/s]
# Loading images into memory:   4%|▍         | 196/4952 [02:13<52:20,  1.51it/s]
# Loading images into memory:   4%|▍         | 197/4952 [02:13<51:58,  1.52it/s]
# Loading images into memory:   4%|▍         | 198/4952 [02:14<51:20,  1.54it/s]
# Loading images into memory:   4%|▍         | 199/4952 [02:15<53:16,  1.49it/s]
# Loading images into memory:   4%|▍         | 200/4952 [02:15<49:38,  1.60it/s]
# Loading images into memory:   4%|▍         | 201/4952 [02:16<50:20,  1.57it/s]
# Loading images into memory:   4%|▍         | 202/4952 [02:16<48:53,  1.62it/s]
# Loading images into memory:   4%|▍         | 203/4952 [02:17<47:17,  1.67it/s]
# Loading images into memory:   4%|▍         | 204/4952 [02:18<49:32,  1.60it/s]
# Loading images into memory:   4%|▍         | 205/4952 [02:19<57:12,  1.38it/s]
# Loading images into memory:   4%|▍         | 206/4952 [02:19<56:19,  1.40it/s]
# Loading images into memory:   4%|▍         | 207/4952 [02:20<53:47,  1.47it/s]
# Loading images into memory:   4%|▍         | 208/4952 [02:21<54:25,  1.45it/s]
# Loading images into memory:   4%|▍         | 209/4952 [02:21<59:08,  1.34it/s]
# Loading images into memory:   4%|▍         | 210/4952 [02:22<55:32,  1.42it/s]
# Loading images into memory:   4%|▍         | 211/4952 [02:23<51:42,  1.53it/s]
# Loading images into memory:   4%|▍         | 212/4952 [02:23<48:12,  1.64it/s]
# Loading images into memory:   4%|▍         | 213/4952 [02:24<45:30,  1.74it/s]
# Loading images into memory:   4%|▍         | 214/4952 [02:24<45:00,  1.75it/s]
# Loading images into memory:   4%|▍         | 215/4952 [02:25<43:41,  1.81it/s]
# Loading images into memory:   4%|▍         | 216/4952 [02:25<47:41,  1.65it/s]
# Loading images into memory:   4%|▍         | 217/4952 [02:26<45:22,  1.74it/s]
# Loading images into memory:   4%|▍         | 218/4952 [02:27<48:34,  1.62it/s]
# Loading images into memory:   4%|▍         | 219/4952 [02:27<50:37,  1.56it/s]
# Loading images into memory:   4%|▍         | 220/4952 [02:28<54:31,  1.45it/s]
# Loading images into memory:   4%|▍         | 221/4952 [02:29<53:46,  1.47it/s]
# Loading images into memory:   4%|▍         | 222/4952 [02:29<53:09,  1.48it/s]
# Loading images into memory:   5%|▍         | 223/4952 [02:32<1:31:19,  1.16s/it]
# Loading images into memory:   5%|▍         | 224/4952 [02:33<1:23:28,  1.06s/it]
# Loading images into memory:   5%|▍         | 225/4952 [02:34<1:36:12,  1.22s/it]
# Loading images into memory:   5%|▍         | 226/4952 [02:35<1:20:42,  1.02s/it]
# Loading images into memory:   5%|▍         | 227/4952 [02:35<1:13:32,  1.07it/s]
# Loading images into memory:   5%|▍         | 228/4952 [02:36<1:09:03,  1.14it/s]
# Loading images into memory:   5%|▍         | 229/4952 [02:38<1:19:26,  1.01s/it]
# Loading images into memory:   5%|▍         | 230/4952 [02:39<1:18:37,  1.00it/s]
# Loading images into memory:   5%|▍         | 231/4952 [02:39<1:07:39,  1.16it/s]
# Loading images into memory:   5%|▍         | 232/4952 [02:40<1:15:24,  1.04it/s]
# Loading images into memory:   5%|▍         | 233/4952 [02:41<1:21:22,  1.03s/it]
# Loading images into memory:   5%|▍         | 234/4952 [02:42<1:14:56,  1.05it/s]
# Loading images into memory:   5%|▍         | 235/4952 [02:43<1:05:10,  1.21it/s]
# Loading images into memory:   5%|▍         | 236/4952 [02:43<58:02,  1.35it/s]
# Loading images into memory:   5%|▍         | 237/4952 [02:44<54:07,  1.45it/s]
# Loading images into memory:   5%|▍         | 238/4952 [02:45<54:37,  1.44it/s]
# Loading images into memory:   5%|▍         | 239/4952 [02:45<55:46,  1.41it/s]
# Loading images into memory:   5%|▍         | 240/4952 [02:46<55:52,  1.41it/s]
# Loading images into memory:   5%|▍         | 241/4952 [02:47<52:50,  1.49it/s]
# Loading images into memory:   5%|▍         | 242/4952 [02:47<48:30,  1.62it/s]
# Loading images into memory:   5%|▍         | 243/4952 [02:48<47:54,  1.64it/s]
# Loading images into memory:   5%|▍         | 244/4952 [02:48<47:30,  1.65it/s]
# Loading images into memory:   5%|▍         | 245/4952 [02:49<45:53,  1.71it/s]
# Loading images into memory:   5%|▍         | 246/4952 [02:49<44:24,  1.77it/s]
# Loading images into memory:   5%|▍         | 247/4952 [02:50<47:44,  1.64it/s]
# Loading images into memory:   5%|▌         | 248/4952 [02:51<52:03,  1.51it/s]
# Loading images into memory:   5%|▌         | 249/4952 [02:51<51:44,  1.51it/s]
# Loading images into memory:   7%|▋         | 324/4952 [03:45<1:36:30,  1.25s/it]
# Loading images into memory:   7%|▋         | 325/4952 [03:45<1:20:23,  1.04s/it]
# Loading images into memory:   7%|▋         | 326/4952 [03:46<1:24:47,  1.10s/it]
# Loading images into memory:   7%|▋         | 327/4952 [03:48<1:42:39,  1.33s/it]
# Loading images into memory:   7%|▋         | 328/4952 [03:49<1:26:57,  1.13s/it]
# Loading images into memory:   7%|▋         | 329/4952 [03:49<1:13:57,  1.04it/s]
# Loading images into memory:   7%|▋         | 330/4952 [03:50<1:05:51,  1.17it/s]
# Loading images into memory:   7%|▋         | 331/4952 [03:51<58:01,  1.33it/s]
# Loading images into memory:   7%|▋         | 332/4952 [03:51<52:40,  1.46it/s]
# Loading images into memory:   7%|▋         | 333/4952 [03:54<1:37:51,  1.27s/it]
# Loading images into memory:   7%|▋         | 334/4952 [03:55<1:25:09,  1.11s/it]
# Loading images into memory:   7%|▋         | 335/4952 [03:56<1:25:13,  1.11s/it]
# Loading images into memory:   7%|▋         | 336/4952 [03:58<1:44:33,  1.36s/it]
# Loading images into memory:   7%|▋         | 337/4952 [03:59<1:38:09,  1.28s/it]
# Loading images into memory:   7%|▋         | 338/4952 [04:00<1:30:45,  1.18s/it]
# Loading images into memory:   7%|▋         | 339/4952 [04:00<1:20:15,  1.04s/it]
# Loading images into memory:   7%|▋         | 340/4952 [04:01<1:08:13,  1.13it/s]
# Loading images into memory:   7%|▋         | 341/4952 [04:01<1:00:40,  1.27it/s]
# Loading images into memory:   7%|▋         | 342/4952 [04:02<57:55,  1.33it/s]
# Loading images into memory:   7%|▋         | 343/4952 [04:03<56:11,  1.37it/s]
# Loading images into memory:   7%|▋         | 344/4952 [04:04<58:41,  1.31it/s]
# Loading images into memory:   7%|▋         | 345/4952 [04:04<57:44,  1.33it/s]
# Loading images into memory:   7%|▋         | 346/4952 [04:05<1:06:35,  1.15it/s]
# Loading images into memory:   7%|▋         | 347/4952 [04:06<59:29,  1.29it/s]
# Loading images into memory:   7%|▋         | 348/4952 [04:07<59:12,  1.30it/s]
# Loading images into memory:   7%|▋         | 349/4952 [04:08<59:46,  1.28it/s]
# Loading images into memory:   7%|▋         | 350/4952 [04:08<53:30,  1.43it/s]
# Loading images into memory:   7%|▋         | 351/4952 [04:09<50:05,  1.53it/s]
# Loading images into memory:   7%|▋         | 352/4952 [04:09<51:50,  1.48it/s]
# Loading images into memory:   7%|▋         | 353/4952 [04:10<58:32,  1.31it/s]
# Loading images into memory:   7%|▋         | 354/4952 [04:11<54:06,  1.42it/s]
# Loading images into memory:   7%|▋         | 355/4952 [04:12<1:00:22,  1.27it/s]
# Loading images into memory:   7%|▋         | 356/4952 [04:13<59:49,  1.28it/s]
# Loading images into memory:   7%|▋         | 357/4952 [04:13<54:51,  1.40it/s]
# Loading images into memory:   7%|▋         | 358/4952 [04:14<50:57,  1.50it/s]
# Loading images into memory:   7%|▋         | 359/4952 [04:14<47:36,  1.61it/s]
# Loading images into memory:   7%|▋         | 360/4952 [04:15<47:14,  1.62it/s]
# Loading images into memory:   7%|▋         | 361/4952 [04:15<44:57,  1.70it/s]
# Loading images into memory:   7%|▋         | 362/4952 [04:16<48:10,  1.59it/s]
# Loading images into memory:   7%|▋         | 363/4952 [04:17<45:53,  1.67it/s]
# Loading images into memory:   7%|▋         | 364/4952 [04:17<46:07,  1.66it/s]
# Loading images into memory:   7%|▋         | 365/4952 [04:18<49:01,  1.56it/s]
# Loading images into memory:   7%|▋         | 366/4952 [04:18<45:23,  1.68it/s]
# Loading images into memory:   7%|▋         | 367/4952 [04:19<46:36,  1.64it/s]
# Loading images into memory:   7%|▋         | 368/4952 [04:20<45:46,  1.67it/s]
# Loading images into memory:   7%|▋         | 369/4952 [04:20<48:08,  1.59it/s]
# Loading images into memory:   7%|▋         | 370/4952 [04:21<47:26,  1.61it/s]
# Loading images into memory:   7%|▋         | 371/4952 [04:22<44:43,  1.71it/s]
# Loading images into memory:   8%|▊         | 372/4952 [04:22<45:20,  1.68it/s]
# Loading images into memory:   8%|▊         | 373/4952 [04:23<44:50,  1.70it/s]
# Loading images into memory:   8%|▊         | 374/4952 [04:23<42:57,  1.78it/s]
# Loading images into memory:   8%|▊         | 375/4952 [04:24<47:09,  1.62it/s]
# Loading images into memory:   8%|▊         | 376/4952 [04:24<44:48,  1.70it/s]
# Loading images into memory:   8%|▊         | 377/4952 [04:25<43:00,  1.77it/s]
# Loading images into memory:   8%|▊         | 378/4952 [04:26<48:13,  1.58it/s]
# Loading images into memory:   8%|▊         | 379/4952 [04:26<46:38,  1.63it/s]
# Loading images into memory:   8%|▊         | 380/4952 [04:27<45:21,  1.68it/s]
# Loading images into memory:   8%|▊         | 381/4952 [04:27<43:12,  1.76it/s]
# Loading images into memory:   8%|▊         | 382/4952 [04:28<42:38,  1.79it/s]
# Loading images into memory:   8%|▊         | 383/4952 [04:30<1:26:50,  1.14s/it]
# Loading images into memory:   8%|▊         | 384/4952 [04:31<1:16:31,  1.01s/it]
# Loading images into memory:   8%|▊         | 385/4952 [04:32<1:19:48,  1.05s/it]
# Loading images into memory:   8%|▊         | 386/4952 [04:33<1:13:14,  1.04it/s]
# Loading images into memory:   8%|▊         | 387/4952 [04:34<1:02:21,  1.22it/s]
# Loading images into memory:   8%|▊         | 388/4952 [04:34<56:05,  1.36it/s]
# Loading images into memory:   8%|▊         | 389/4952 [04:35<56:17,  1.35it/s]
# Loading images into memory:   8%|▊         | 390/4952 [04:36<1:01:11,  1.24it/s]
# Loading images into memory:   8%|▊         | 391/4952 [04:37<59:39,  1.27it/s]
# Loading images into memory:   8%|▊         | 392/4952 [04:37<56:14,  1.35it/s]
# Loading images into memory:   8%|▊         | 393/4952 [04:38<57:01,  1.33it/s]
# Loading images into memory:   8%|▊         | 394/4952 [04:38<52:35,  1.44it/s]
# Loading images into memory:   8%|▊         | 395/4952 [04:39<48:30,  1.57it/s]
# Loading images into memory:   8%|▊         | 396/4952 [04:40<48:01,  1.58it/s]
# Loading images into memory:   8%|▊         | 397/4952 [04:40<51:19,  1.48it/s]
# Loading images into memory:   8%|▊         | 398/4952 [04:41<49:17,  1.54it/s]
# Loading images into memory:   8%|▊         | 399/4952 [04:42<53:34,  1.42it/s]
# Loading images into memory:   8%|▊         | 400/4952 [04:42<50:25,  1.50it/s]
# Loading images into memory:   8%|▊         | 401/4952 [04:49<3:08:09,  2.48s/it]
# Loading images into memory:   8%|▊         | 402/4952 [04:50<2:25:01,  1.91s/it]
# Loading images into memory:   8%|▊         | 403/4952 [04:51<2:01:05,  1.60s/it]
# Loading images into memory:   8%|▊         | 404/4952 [04:51<1:42:08,  1.35s/it]
# Loading images into memory:   8%|▊         | 405/4952 [04:52<1:25:47,  1.13s/it]
# Loading images into memory:   8%|▊         | 406/4952 [04:53<1:13:00,  1.04it/s]
# Loading images into memory:   8%|▊         | 407/4952 [04:54<1:14:16,  1.02it/s]
# Loading images into memory:   8%|▊         | 408/4952 [04:54<1:06:01,  1.15it/s]
# Loading images into memory:   8%|▊         | 409/4952 [04:55<59:59,  1.26it/s]
# Loading images into memory:   8%|▊         | 410/4952 [04:55<56:45,  1.33it/s]
# Loading images into memory:   8%|▊         | 411/4952 [04:56<55:59,  1.35it/s]
# Loading images into memory:   8%|▊         | 412/4952 [04:57<51:07,  1.48it/s]
# Loading images into memory:   8%|▊         | 413/4952 [04:57<48:54,  1.55it/s]
# Loading images into memory:   8%|▊         | 414/4952 [04:58<46:24,  1.63it/s]
# Loading images into memory:   8%|▊         | 415/4952 [04:58<48:58,  1.54it/s]
# Loading images into memory:   8%|▊         | 416/4952 [04:59<47:05,  1.61it/s]
# Loading images into memory:   8%|▊         | 417/4952 [05:00<46:00,  1.64it/s]
# Loading images into memory:   8%|▊         | 418/4952 [05:00<47:07,  1.60it/s]
# Loading images into memory:   8%|▊         | 419/4952 [05:01<46:26,  1.63it/s]
# Loading images into memory:   8%|▊         | 420/4952 [05:01<45:55,  1.64it/s]
# Loading images into memory:   9%|▊         | 421/4952 [05:02<51:32,  1.46it/s]
# Loading images into memory:   9%|▊         | 422/4952 [05:03<51:36,  1.46it/s]
# Loading images into memory:   9%|▊         | 423/4952 [05:04<47:53,  1.58it/s]
# Loading images into memory:   9%|▊         | 424/4952 [05:04<50:00,  1.51it/s]
# Loading images into memory:   9%|▊         | 425/4952 [05:05<47:47,  1.58it/s]
# Loading images into memory:   9%|▊         | 426/4952 [05:06<54:37,  1.38it/s]
# Loading images into memory:   9%|▊         | 427/4952 [05:06<51:15,  1.47it/s]
# Loading images into memory:   9%|▊         | 428/4952 [05:07<49:13,  1.53it/s]
# Loading images into memory:   9%|▊         | 429/4952 [05:08<52:53,  1.43it/s]
# Loading images into memory:   9%|▊         | 430/4952 [05:08<53:11,  1.42it/s]
# Loading images into memory:   9%|▊         | 431/4952 [05:09<54:31,  1.38it/s]
# Loading images into memory:   9%|▊         | 432/4952 [05:10<53:42,  1.40it/s]
# Loading images into memory:   9%|▊         | 433/4952 [05:11<50:50,  1.48it/s]
# Loading images into memory:   9%|▉         | 434/4952 [05:11<51:29,  1.46it/s]
# Loading images into memory:   9%|▉         | 435/4952 [05:12<50:39,  1.49it/s]
# Loading images into memory:   9%|▉         | 436/4952 [05:12<49:12,  1.53it/s]
# Loading images into memory:   9%|▉         | 437/4952 [05:13<57:41,  1.30it/s]
# Loading images into memory:   9%|▉         | 438/4952 [05:14<52:05,  1.44it/s]
# Loading images into memory:   9%|▉         | 439/4952 [05:15<48:39,  1.55it/s]
# Loading images into memory:   9%|▉         | 440/4952 [05:15<45:08,  1.67it/s]
# Loading images into memory:   9%|▉         | 441/4952 [05:16<48:37,  1.55it/s]
# Loading images into memory:   9%|▉         | 442/4952 [05:17<56:47,  1.32it/s]
# Loading images into memory:   9%|▉         | 443/4952 [05:18<1:01:52,  1.21it/s]
# Loading images into memory:   9%|▉         | 444/4952 [05:18<54:46,  1.37it/s]
# Loading images into memory:   9%|▉         | 445/4952 [05:19<49:44,  1.51it/s]
# Loading images into memory:   9%|▉         | 446/4952 [05:20<52:00,  1.44it/s]
# Loading images into memory:   9%|▉         | 447/4952 [05:20<48:54,  1.54it/s]
# Loading images into memory:   9%|▉         | 448/4952 [05:21<47:27,  1.58it/s]
# Loading images into memory:   9%|▉         | 449/4952 [05:21<46:01,  1.63it/s]
# Loading images into memory:   9%|▉         | 450/4952 [05:24<1:31:09,  1.21s/it]
# Loading images into memory:   9%|▉         | 451/4952 [05:25<1:25:48,  1.14s/it]
# Loading images into memory:   9%|▉         | 452/4952 [05:25<1:12:42,  1.03it/s]
# Loading images into memory:   9%|▉         | 453/4952 [05:26<1:03:53,  1.17it/s]
# Loading images into memory:   9%|▉         | 454/4952 [05:27<1:01:56,  1.21it/s]
# Loading images into memory:   9%|▉         | 455/4952 [05:27<56:54,  1.32it/s]
# Loading images into memory:   9%|▉         | 456/4952 [05:28<57:50,  1.30it/s]
# Loading images into memory:   9%|▉         | 457/4952 [05:29<52:54,  1.42it/s]
# Loading images into memory:   9%|▉         | 458/4952 [05:29<52:21,  1.43it/s]
# Loading images into memory:   9%|▉         | 459/4952 [05:30<50:21,  1.49it/s]
# Loading images into memory:   9%|▉         | 460/4952 [05:31<51:41,  1.45it/s]
# Loading images into memory:   9%|▉         | 461/4952 [05:32<54:24,  1.38it/s]
# Loading images into memory:   9%|▉         | 462/4952 [05:32<52:15,  1.43it/s]
# Loading images into memory:   9%|▉         | 463/4952 [05:33<48:00,  1.56it/s]
# Loading images into memory:   9%|▉         | 464/4952 [05:33<46:57,  1.59it/s]
# Loading images into memory:   9%|▉         | 465/4952 [05:34<46:33,  1.61it/s]
# Loading images into memory:   9%|▉         | 466/4952 [05:34<44:04,  1.70it/s]
# Loading images into memory:   9%|▉         | 467/4952 [05:35<42:09,  1.77it/s]
# Loading images into memory:   9%|▉         | 468/4952 [05:35<40:33,  1.84it/s]
# Loading images into memory:   9%|▉         | 469/4952 [05:36<40:08,  1.86it/s]
# Loading images into memory:   9%|▉         | 470/4952 [05:37<43:26,  1.72it/s]
# Loading images into memory:  10%|▉         | 471/4952 [05:37<47:06,  1.59it/s]
# Loading images into memory:  10%|█         | 509/4952 [06:04<50:03,  1.48it/s]
# Loading images into memory:  10%|█         | 510/4952 [06:05<46:32,  1.59it/s]
# Loading images into memory:  10%|█         | 511/4952 [06:05<46:26,  1.59it/s]
# Loading images into memory:  10%|█         | 512/4952 [06:06<55:18,  1.34it/s]
# Loading images into memory:  10%|█         | 513/4952 [06:07<52:55,  1.40it/s]
# Loading images into memory:  10%|█         | 514/4952 [06:08<51:52,  1.43it/s]
# Loading images into memory:  10%|█         | 515/4952 [06:08<49:55,  1.48it/s]
# Loading images into memory:  10%|█         | 516/4952 [06:09<48:42,  1.52it/s]
# Loading images into memory:  10%|█         | 517/4952 [06:09<46:48,  1.58it/s]
# Loading images into memory:  10%|█         | 518/4952 [06:10<47:28,  1.56it/s]
# Loading images into memory:  10%|█         | 519/4952 [06:11<45:33,  1.62it/s]
# Loading images into memory:  11%|█         | 520/4952 [06:11<48:23,  1.53it/s]
# Loading images into memory:  11%|█         | 521/4952 [06:12<45:34,  1.62it/s]
# Loading images into memory:  11%|█         | 522/4952 [06:12<46:06,  1.60it/s]
# Loading images into memory:  11%|█         | 523/4952 [06:13<49:52,  1.48it/s]
# Loading images into memory:  11%|█         | 524/4952 [06:14<47:45,  1.55it/s]
# Loading images into memory:  11%|█         | 525/4952 [06:14<44:50,  1.65it/s]
# Loading images into memory:  11%|█         | 526/4952 [06:15<42:19,  1.74it/s]
# Loading images into memory:  11%|█         | 527/4952 [06:15<42:59,  1.72it/s]
# Loading images into memory:  11%|█         | 528/4952 [06:16<42:33,  1.73it/s]
# Loading images into memory:  11%|█         | 529/4952 [06:17<50:38,  1.46it/s]
# Loading images into memory:  11%|█         | 530/4952 [06:18<50:38,  1.46it/s]
# Loading images into memory:  11%|█         | 531/4952 [06:18<47:52,  1.54it/s]
# Loading images into memory:  11%|█         | 532/4952 [06:19<47:37,  1.55it/s]
# Loading images into memory:  11%|█         | 533/4952 [06:20<54:45,  1.35it/s]
# Loading images into memory:  11%|█         | 534/4952 [06:21<58:21,  1.26it/s]
# Loading images into memory:  11%|█         | 535/4952 [06:21<54:04,  1.36it/s]
# Loading images into memory:  11%|█         | 536/4952 [06:22<53:27,  1.38it/s]
# Loading images into memory:  11%|█         | 537/4952 [06:23<52:34,  1.40it/s]
# Loading images into memory:  11%|█         | 538/4952 [06:24<58:06,  1.27it/s]
# Loading images into memory:  11%|█         | 539/4952 [06:25<1:03:27,  1.16it/s]
# Loading images into memory:  11%|█         | 540/4952 [06:25<57:58,  1.27it/s]
# Loading images into memory:  11%|█         | 541/4952 [06:26<58:38,  1.25it/s]
# Loading images into memory:  11%|█         | 542/4952 [06:29<1:44:39,  1.42s/it]
# Loading images into memory:  11%|█         | 543/4952 [06:30<1:29:17,  1.22s/it]
# Loading images into memory:  11%|█         | 544/4952 [06:30<1:14:57,  1.02s/it]
# Loading images into memory:  11%|█         | 545/4952 [06:31<1:05:44,  1.12it/s]
# Loading images into memory:  11%|█         | 546/4952 [06:32<1:00:57,  1.20it/s]
# Loading images into memory:  11%|█         | 547/4952 [06:32<58:04,  1.26it/s]
# Loading images into memory:  11%|█         | 548/4952 [06:34<1:15:15,  1.03s/it]
# Loading images into memory:  11%|█         | 549/4952 [06:34<1:04:21,  1.14it/s]
# Loading images into memory:  11%|█         | 550/4952 [06:35<57:35,  1.27it/s]
# Loading images into memory:  11%|█         | 551/4952 [06:36<51:56,  1.41it/s]
# Loading images into memory:  11%|█         | 552/4952 [06:36<50:59,  1.44it/s]
# Loading images into memory:  11%|█         | 553/4952 [06:37<47:37,  1.54it/s]
# Loading images into memory:  11%|█         | 554/4952 [06:37<44:35,  1.64it/s]
# Loading images into memory:  11%|█         | 555/4952 [06:38<45:12,  1.62it/s]
# ...
# Loading images into memory:  96%|█████████▌| 4759/4952 [57:12<02:13,  1.45it/s]
# Loading images into memory:  96%|█████████▌| 4760/4952 [57:13<02:02,  1.56it/s]
# Loading images into memory:  96%|█████████▌| 4761/4952 [57:14<02:02,  1.56it/s]
# Loading images into memory:  96%|█████████▌| 4762/4952 [57:14<02:08,  1.47it/s]
# Loading images into memory:  96%|█████████▌| 4763/4952 [57:15<02:15,  1.40it/s]
# Loading images into memory:  96%|█████████▌| 4764/4952 [57:16<02:05,  1.50it/s]
# Loading images into memory:  96%|█████████▌| 4765/4952 [57:16<02:07,  1.47it/s]
# Loading images into memory:  96%|█████████▌| 4766/4952 [57:17<02:01,  1.53it/s]
# Loading images into memory:  96%|█████████▋| 4767/4952 [57:18<01:54,  1.62it/s]
# Loading images into memory:  96%|█████████▋| 4768/4952 [57:18<02:01,  1.51it/s]
# Loading images into memory:  96%|█████████▋| 4769/4952 [57:19<02:00,  1.52it/s]
# Loading images into memory:  96%|█████████▋| 4770/4952 [57:20<02:04,  1.47it/s]
# Loading images into memory:  96%|█████████▋| 4771/4952 [57:20<02:00,  1.50it/s]
# Loading images into memory:  96%|█████████▋| 4772/4952 [57:21<02:02,  1.47it/s]
# Loading images into memory:  96%|█████████▋| 4773/4952 [57:22<01:54,  1.57it/s]
# Loading images into memory:  96%|█████████▋| 4774/4952 [57:22<01:52,  1.58it/s]
# Loading images into memory:  96%|█████████▋| 4775/4952 [57:23<01:59,  1.48it/s]
# Loading images into memory:  96%|█████████▋| 4776/4952 [57:24<01:52,  1.56it/s]
# Loading images into memory:  96%|█████████▋| 4777/4952 [57:24<01:47,  1.63it/s]
# Loading images into memory:  96%|█████████▋| 4778/4952 [57:25<01:45,  1.66it/s]
# Loading images into memory:  97%|█████████▋| 4779/4952 [57:25<01:51,  1.55it/s]
# Loading images into memory:  97%|█████████▋| 4780/4952 [57:26<01:48,  1.59it/s]
# Loading images into memory:  97%|█████████▋| 4781/4952 [57:27<01:45,  1.63it/s]
# Loading images into memory:  97%|█████████▋| 4782/4952 [57:27<01:51,  1.53it/s]
# Loading images into memory:  97%|█████████▋| 4783/4952 [57:28<01:42,  1.64it/s]
# Loading images into memory:  97%|█████████▋| 4784/4952 [57:29<01:43,  1.62it/s]
# Loading images into memory:  97%|█████████▋| 4785/4952 [57:29<01:49,  1.53it/s]
# Loading images into memory:  97%|█████████▋| 4786/4952 [57:30<01:48,  1.53it/s]
# Loading images into memory:  97%|█████████▋| 4787/4952 [57:30<01:42,  1.61it/s]
# Loading images into memory:  97%|█████████▋| 4788/4952 [57:31<01:46,  1.54it/s]
# Loading images into memory:  97%|█████████▋| 4789/4952 [57:32<01:39,  1.64it/s]
# Loading images into memory:  97%|█████████▋| 4790/4952 [57:32<01:35,  1.69it/s]
# Loading images into memory:  97%|█████████▋| 4791/4952 [57:33<01:34,  1.70it/s]
# Loading images into memory:  97%|█████████▋| 4792/4952 [57:34<01:41,  1.58it/s]
# Loading images into memory:  97%|█████████▋| 4793/4952 [57:35<02:06,  1.26it/s]
# Loading images into memory:  97%|█████████▋| 4794/4952 [57:36<02:15,  1.17it/s]
# Loading images into memory:  97%|█████████▋| 4795/4952 [57:36<02:06,  1.24it/s]
# Loading images into memory:  97%|█████████▋| 4796/4952 [57:37<01:53,  1.37it/s]
# Loading images into memory:  97%|█████████▋| 4797/4952 [57:38<01:56,  1.33it/s]
# Loading images into memory:  97%|█████████▋| 4798/4952 [57:39<02:00,  1.28it/s]
# Loading images into memory:  97%|█████████▋| 4799/4952 [57:39<01:57,  1.30it/s]
# Loading images into memory:  97%|█████████▋| 4800/4952 [57:40<01:45,  1.44it/s]
# Loading images into memory:  97%|█████████▋| 4801/4952 [57:40<01:39,  1.52it/s]
# Loading images into memory:  97%|█████████▋| 4802/4952 [57:41<01:33,  1.60it/s]
# Loading images into memory:  97%|█████████▋| 4803/4952 [57:42<01:29,  1.66it/s]
# Loading images into memory:  97%|█████████▋| 4804/4952 [57:42<01:29,  1.66it/s]
# Loading images into memory:  97%|█████████▋| 4805/4952 [57:43<01:37,  1.51it/s]
# Loading images into memory:  97%|█████████▋| 4806/4952 [57:44<01:36,  1.52it/s]
# Loading images into memory:  97%|█████████▋| 4807/4952 [57:44<01:34,  1.53it/s]
# Loading images into memory:  97%|█████████▋| 4808/4952 [57:45<01:34,  1.53it/s]
# Loading images into memory:  97%|█████████▋| 4809/4952 [57:46<01:37,  1.47it/s]
# Loading images into memory:  97%|█████████▋| 4810/4952 [57:46<01:34,  1.50it/s]
# Loading images into memory:  97%|█████████▋| 4811/4952 [57:47<01:34,  1.49it/s]
# Loading images into memory:  97%|█████████▋| 4812/4952 [57:48<01:33,  1.50it/s]
# Loading images into memory:  97%|█████████▋| 4813/4952 [57:48<01:29,  1.55it/s]
# Loading images into memory:  97%|█████████▋| 4814/4952 [57:49<01:32,  1.49it/s]
# Loading images into memory:  97%|█████████▋| 4815/4952 [57:50<01:36,  1.42it/s]
# Loading images into memory:  97%|█████████▋| 4816/4952 [57:50<01:36,  1.40it/s]
# Loading images into memory:  97%|█████████▋| 4817/4952 [57:51<01:34,  1.43it/s]
# Loading images into memory:  97%|█████████▋| 4818/4952 [57:52<01:27,  1.53it/s]
# Loading images into memory:  97%|█████████▋| 4819/4952 [57:52<01:26,  1.55it/s]
# Loading images into memory:  97%|█████████▋| 4820/4952 [57:53<01:31,  1.44it/s]
# Loading images into memory:  97%|█████████▋| 4821/4952 [57:54<01:26,  1.51it/s]
# Loading images into memory:  97%|█████████▋| 4822/4952 [57:56<02:12,  1.02s/it]
# Loading images into memory:  97%|█████████▋| 4823/4952 [57:56<01:59,  1.08it/s]
# Loading images into memory:  97%|█████████▋| 4824/4952 [57:57<01:46,  1.20it/s]
# Loading images into memory:  97%|█████████▋| 4825/4952 [57:57<01:33,  1.36it/s]
# Loading images into memory:  97%|█████████▋| 4826/4952 [57:58<01:43,  1.21it/s]
# Loading images into memory:  97%|█████████▋| 4827/4952 [57:59<01:35,  1.31it/s]
# Loading images into memory:  97%|█████████▋| 4828/4952 [58:00<01:32,  1.33it/s]
# Loading images into memory:  98%|█████████▊| 4829/4952 [58:00<01:23,  1.48it/s]
# Loading images into memory:  98%|█████████▊| 4830/4952 [58:01<01:15,  1.61it/s]
# Loading images into memory:  98%|█████████▊| 4831/4952 [58:02<01:28,  1.36it/s]
# Loading images into memory:  98%|█████████▊| 4832/4952 [58:03<01:30,  1.33it/s]
# Loading images into memory:  98%|█████████▊| 4833/4952 [58:03<01:22,  1.44it/s]
# Loading images into memory:  98%|█████████▊| 4834/4952 [58:04<01:17,  1.53it/s]
# Loading images into memory:  98%|█████████▊| 4835/4952 [58:04<01:15,  1.55it/s]
# Loading images into memory:  98%|█████████▊| 4836/4952 [58:05<01:16,  1.51it/s]
# Loading images into memory:  98%|█████████▊| 4837/4952 [58:06<01:12,  1.59it/s]
# Loading images into memory:  98%|█████████▊| 4838/4952 [58:06<01:11,  1.59it/s]
# Loading images into memory:  98%|█████████▊| 4839/4952 [58:07<01:15,  1.50it/s]
# Loading images into memory:  98%|█████████▊| 4840/4952 [58:08<01:14,  1.49it/s]
# Loading images into memory:  98%|█████████▊| 4841/4952 [58:08<01:09,  1.61it/s]
# Loading images into memory:  98%|█████████▊| 4842/4952 [58:09<01:21,  1.35it/s]
# Loading images into memory:  98%|█████████▊| 4843/4952 [58:10<01:13,  1.47it/s]
# Loading images into memory:  98%|█████████▊| 4844/4952 [58:10<01:13,  1.47it/s]
# Loading images into memory:  98%|█████████▊| 4845/4952 [58:11<01:10,  1.53it/s]
# Loading images into memory:  98%|█████████▊| 4846/4952 [58:11<01:05,  1.61it/s]
# Loading images into memory:  98%|█████████▊| 4847/4952 [58:12<01:12,  1.44it/s]
# Loading images into memory:  98%|█████████▊| 4848/4952 [58:13<01:09,  1.51it/s]
# Loading images into memory:  98%|█████████▊| 4849/4952 [58:14<01:08,  1.51it/s]
# Loading images into memory:  98%|█████████▊| 4850/4952 [58:14<01:05,  1.55it/s]
# Loading images into memory:  98%|█████████▊| 4851/4952 [58:15<01:04,  1.57it/s]
# Loading images into memory:  98%|█████████▊| 4852/4952 [58:16<01:11,  1.40it/s]
# Loading images into memory:  98%|█████████▊| 4853/4952 [58:16<01:07,  1.47it/s]
# Loading images into memory:  98%|█████████▊| 4854/4952 [58:17<01:06,  1.47it/s]
# Loading images into memory:  98%|█████████▊| 4855/4952 [58:18<01:06,  1.47it/s]
# Loading images into memory:  98%|█████████▊| 4856/4952 [58:18<01:04,  1.48it/s]
# Loading images into memory:  98%|█████████▊| 4857/4952 [58:19<01:05,  1.45it/s]
# Loading images into memory:  98%|█████████▊| 4858/4952 [58:20<01:07,  1.40it/s]
# Loading images into memory:  98%|█████████▊| 4859/4952 [58:20<01:00,  1.54it/s]
# Loading images into memory:  98%|█████████▊| 4860/4952 [58:21<01:05,  1.41it/s]
# Loading images into memory:  98%|█████████▊| 4861/4952 [58:22<01:07,  1.36it/s]
# Loading images into memory:  98%|█████████▊| 4862/4952 [58:23<01:01,  1.46it/s]
# Loading images into memory:  98%|█████████▊| 4863/4952 [58:23<01:03,  1.40it/s]
# Loading images into memory:  98%|█████████▊| 4864/4952 [58:24<01:04,  1.37it/s]
# Loading images into memory:  98%|█████████▊| 4865/4952 [58:25<00:58,  1.49it/s]
# Loading images into memory:  98%|█████████▊| 4866/4952 [58:25<00:53,  1.61it/s]
# Loading images into memory:  98%|█████████▊| 4867/4952 [58:26<00:56,  1.51it/s]
# Loading images into memory:  98%|█████████▊| 4868/4952 [58:26<00:54,  1.55it/s]
# Loading images into memory:  98%|█████████▊| 4869/4952 [58:27<00:51,  1.61it/s]
# Loading images into memory:  98%|█████████▊| 4870/4952 [58:28<00:49,  1.65it/s]
# Loading images into memory:  98%|█████████▊| 4871/4952 [58:28<00:47,  1.69it/s]
# Loading images into memory:  98%|█████████▊| 4872/4952 [58:29<00:49,  1.61it/s]
# Loading images into memory:  98%|█████████▊| 4873/4952 [58:29<00:47,  1.68it/s]
# Loading images into memory:  98%|█████████▊| 4874/4952 [58:30<00:44,  1.74it/s]
# Loading images into memory:  98%|█████████▊| 4875/4952 [58:31<00:48,  1.58it/s]
# Loading images into memory:  98%|█████████▊| 4876/4952 [58:31<00:51,  1.49it/s]
# Loading images into memory:  98%|█████████▊| 4877/4952 [58:32<00:51,  1.45it/s]
# Loading images into memory:  99%|█████████▊| 4878/4952 [58:33<00:47,  1.55it/s]
# Loading images into memory:  99%|█████████▊| 4879/4952 [58:33<00:45,  1.59it/s]
# Loading images into memory:  99%|█████████▊| 4880/4952 [58:34<00:42,  1.68it/s]
# Loading images into memory:  99%|█████████▊| 4881/4952 [58:34<00:39,  1.78it/s]
# Loading images into memory:  99%|█████████▊| 4882/4952 [58:35<00:42,  1.66it/s]
# Loading images into memory:  99%|█████████▊| 4883/4952 [58:36<00:39,  1.74it/s]
# Loading images into memory:  99%|█████████▊| 4884/4952 [58:36<00:46,  1.47it/s]
# Loading images into memory:  99%|█████████▊| 4885/4952 [58:37<00:41,  1.60it/s]
# Loading images into memory:  99%|█████████▊| 4886/4952 [58:38<00:39,  1.65it/s]
# Loading images into memory:  99%|█████████▊| 4887/4952 [58:38<00:41,  1.58it/s]
# Loading images into memory:  99%|█████████▊| 4888/4952 [58:39<00:41,  1.54it/s]
# Loading images into memory:  99%|█████████▊| 4889/4952 [58:40<00:41,  1.53it/s]
# Loading images into memory:  99%|█████████▉| 4925/4952 [59:07<00:17,  1.59it/s]
# Loading images into memory:  99%|█████████▉| 4926/4952 [59:08<00:17,  1.46it/s]
# Loading images into memory:  99%|█████████▉| 4927/4952 [59:08<00:15,  1.60it/s]
# Loading images into memory: 100%|█████████▉| 4928/4952 [59:09<00:16,  1.50it/s]
# Loading images into memory: 100%|█████████▉| 4929/4952 [59:10<00:14,  1.58it/s]
# Loading images into memory: 100%|█████████▉| 4930/4952 [59:10<00:13,  1.68it/s]
# Loading images into memory: 100%|█████████▉| 4931/4952 [59:11<00:12,  1.75it/s]
# Loading images into memory: 100%|█████████▉| 4932/4952 [59:11<00:11,  1.79it/s]
# Loading images into memory: 100%|█████████▉| 4933/4952 [59:12<00:11,  1.61it/s]
# Loading images into memory: 100%|█████████▉| 4934/4952 [59:13<00:11,  1.62it/s]
# Loading images into memory: 100%|█████████▉| 4935/4952 [59:13<00:09,  1.72it/s]
# Loading images into memory: 100%|█████████▉| 4936/4952 [59:14<00:09,  1.71it/s]
# Loading images into memory: 100%|█████████▉| 4937/4952 [59:14<00:08,  1.75it/s]
# Loading images into memory: 100%|█████████▉| 4938/4952 [59:15<00:07,  1.82it/s]
# Loading images into memory: 100%|█████████▉| 4939/4952 [59:16<00:07,  1.66it/s]
# Loading images into memory: 100%|█████████▉| 4940/4952 [59:16<00:07,  1.52it/s]
# Loading images into memory: 100%|█████████▉| 4941/4952 [59:17<00:08,  1.37it/s]
# Loading images into memory: 100%|█████████▉| 4942/4952 [59:18<00:07,  1.40it/s]
# Loading images into memory: 100%|█████████▉| 4943/4952 [59:18<00:05,  1.50it/s]
# Loading images into memory: 100%|█████████▉| 4944/4952 [59:19<00:05,  1.56it/s]
# Loading images into memory: 100%|█████████▉| 4945/4952 [59:20<00:04,  1.47it/s]
# Loading images into memory: 100%|█████████▉| 4946/4952 [59:23<00:08,  1.36s/it]
# Loading images into memory: 100%|█████████▉| 4947/4952 [59:23<00:05,  1.12s/it]
# Loading images into memory: 100%|█████████▉| 4948/4952 [59:24<00:03,  1.06it/s]
# Loading images into memory: 100%|█████████▉| 4949/4952 [59:24<00:02,  1.19it/s]
# Loading images into memory: 100%|█████████▉| 4950/4952 [59:25<00:01,  1.35it/s]
# Loading images into memory: 100%|█████████▉| 4951/4952 [59:25<00:00,  1.46it/s]
# Loading images into memory: 100%|██████████| 4952/4952 [59:27<00:00,  1.39it/s]
# "train_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07+12_trainval.h5',\n                                  resize=False,\n                                  variable_image_size=True,\n                                  verbose=True)\n\nval_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07_test.h5',\n                                resize=False,\n                                variable_image_size=True,\n                                verbose=True)"

# %%
# 3: Set the batch size.

batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  5011
# Number of images in the validation dataset:	  4952

# %% [markdown]
# ## 5. Set the remaining training parameters

# %%
# Define a learning rate schedule.

def lr_schedule(epoch):
    if epoch < 80:
        return 0.001
    elif epoch < 100:
        return 0.0001
    else:
        return 0.00001

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='ssd300_pascal_07_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)

csv_logger = CSVLogger(filename='ssd300_pascal_07_training_log.csv',
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan]

# %% [markdown]
# ## 6. Train

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 120
steps_per_epoch = ceil(train_dataset_size/batch_size)

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 249s 2s/step - loss: 10.9736 - val_loss: 8.4476
#
# Epoch 00001: val_loss improved from inf to 8.44764, saving model to ssd300_pascal_07_epoch-01_loss-10.9802_val_loss-8.4476.h5
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 227s 1s/step - loss: 8.4234 - val_loss: 8.0303
#
# Epoch 00002: val_loss improved from 8.44764 to 8.03028, saving model to ssd300_pascal_07_epoch-02_loss-8.4254_val_loss-8.0303.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 221s 1s/step - loss: 7.9838 - val_loss: 7.6825
#
# Epoch 00003: val_loss improved from 8.03028 to 7.68250, saving model to ssd300_pascal_07_epoch-03_loss-7.9841_val_loss-7.6825.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 218s 1s/step - loss: 7.7361 - val_loss: 7.4892
#
# Epoch 00004: val_loss improved from 7.68250 to 7.48924, saving model to ssd300_pascal_07_epoch-04_loss-7.7347_val_loss-7.4892.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 223s 1s/step - loss: 7.5318 - val_loss: 7.3233
#
# Epoch 00005: val_loss improved from 7.48924 to 7.32334, saving model to ssd300_pascal_07_epoch-05_loss-7.5341_val_loss-7.3233.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 220s 1s/step - loss: 7.3724 - val_loss: 7.4416
#
# Epoch 00006: val_loss did not improve from 7.32334
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 220s 1s/step - loss: 7.3191 - val_loss: 7.2591
#
# Epoch 00007: val_loss improved from 7.32334 to 7.25909, saving model to ssd300_pascal_07_epoch-07_loss-7.3180_val_loss-7.2591.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 223s 1s/step - loss: 7.2294 - val_loss: 7.0320
#
# Epoch 00008: val_loss improved from 7.25909 to 7.03204, saving model to ssd300_pascal_07_epoch-08_loss-7.2301_val_loss-7.0320.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 226s 1s/step - loss: 7.1456 - val_loss: 6.9455
#
# Epoch 00009: val_loss improved from 7.03204 to 6.94554, saving model to ssd300_pascal_07_epoch-09_loss-7.1450_val_loss-6.9455.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 226s 1s/step - loss: 7.0851 - val_loss: 6.9028
#
# Epoch 00010: val_loss improved from 6.94554 to 6.90278, saving model to ssd300_pascal_07_epoch-10_loss-7.0845_val_loss-6.9028.h5
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 224s 1s/step - loss: 6.9857 - val_loss: 6.7951
#
# Epoch 00011: val_loss improved from 6.90278 to 6.79510, saving model to ssd300_pascal_07_epoch-11_loss-6.9861_val_loss-6.7951.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 227s 1s/step - loss: 6.9294 - val_loss: 6.7720
#
# Epoch 00012: val_loss improved from 6.79510 to 6.77203, saving model to ssd300_pascal_07_epoch-12_loss-6.9294_val_loss-6.7720.h5
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 225s 1s/step - loss: 6.8762 - val_loss: 6.6871
#
# Epoch 00013: val_loss improved from 6.77203 to 6.68707, saving model to ssd300_pascal_07_epoch-13_loss-6.8745_val_loss-6.6871.h5
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 224s 1s/step - loss: 6.8167 - val_loss: 6.5396
#
# Epoch 00014: val_loss improved from 6.68707 to 6.53961, saving model to ssd300_pascal_07_epoch-14_loss-6.8170_val_loss-6.5396.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 222s 1s/step - loss: 6.7871 - val_loss: 6.7064
#
# Epoch 00015: val_loss did not improve from 6.53961
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 218s 1s/step - loss: 6.7546 - val_loss: 6.5102
#
# Epoch 00016: val_loss improved from 6.53961 to 6.51021, saving model to ssd300_pascal_07_epoch-16_loss-6.7559_val_loss-6.5102.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 157/157 [==============================] - 218s 1s/step - loss: 6.6788 - val_loss: 6.5677
#
# Epoch 00017: val_loss did not improve from 6.51021
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
#  60/157 [==========>...................] - ETA: 1:33 - loss: 6.6394

# %% [markdown]
# # TRAINING FROM SCRATCH
# [INDEX](#INDEX "Goto INDEX")
# ## Training from pretrained weights
# Pretrained Weights- VGG16<Br>
# New Training- Training for PASCAL VOC 2007 data

# %% [markdown]
# ## 1. Set the model configuration parameters

# %%
# set model parameters
weights_path = 'pretrained_weights/VGG_ILSVRC_16_layers_fc_reduced.h5' # VGG16 model weights path
img_height = 300 # Height of the input images
img_width = 300 # Width of the input images
img_channels = 3 # Number of color channels of the input images
mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. 
n_classes = 20 # set new number of classes to train on
# Do not change this value if you're using any of the pre-trained weights.
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we should set this to `True`, but weirdly the results are better without swapping.
n_classes = 20 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales = scales_pascal
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not you want to limit the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are scaled as in the original implementation
normalize_coords = True

# %% [markdown]
# ## 2. Build or load the model
# ### 2.1 Create a new model and load trained VGG-16 weights into it (or trained SSD weights)

# %%
# 1: Build the Keras model.
K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# 2: Load pretrained weights
model.load_weights(weights_path, by_name=True)

# 3: Instantiate an Adam optimizer and the SSD loss function and compile the model.
adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
# Out:
# W0609 16:30:01.313960  5992 module_wrapper.py:139] From C:\Users\abhinav.jhanwar\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0609 16:30:01.314225  5992 module_wrapper.py:139] From C:\Users\abhinav.jhanwar\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0609 16:30:01.315226  5992 module_wrapper.py:139] From C:\Users\abhinav.jhanwar\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0609 16:30:01.344149  5992 module_wrapper.py:139] From C:\Users\abhinav.jhanwar\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W0609 16:30:01.346146  5992 module_wrapper.py:139] From C:\Users\abhinav.jhanwar\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W0609 16:30:01.513870  5992 module_wrapper.py:139] From C:\Users\abhinav.jhanwar\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# W0609 16:30:02.086343  5992 module_wrapper.py:139] From C:\Users\abhinav.jhanwar\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0609 16:30:02.098339  5992 module_wrapper.py:139] From C:\Users\abhinav.jhanwar\Documents\git\object-detection-classification\ssd\keras_loss_function\keras_ssd_loss.py:95: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0609 16:30:02.102300  5992 deprecation.py:323] From C:\Users\abhinav.jhanwar\Documents\git\object-detection-classification\ssd\keras_loss_function\keras_ssd_loss.py:133: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0609 16:30:02.112270  5992 deprecation.py:323] From C:\Users\abhinav.jhanwar\Documents\git\object-detection-classification\ssd\keras_loss_function\keras_ssd_loss.py:74: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0609 16:30:02.129225  5992 deprecation.py:323] From C:\Users\abhinav.jhanwar\Documents\git\object-detection-classification\ssd\keras_loss_function\keras_ssd_loss.py:166: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %% [markdown]
# ### 2.2 Load a previously created model
# If you have previously created and saved a model and would now like to load it, execute the next code cell. The only thing you need to do here is to set the path to the saved model HDF5 file that you would like to load.
#
# The SSD model contains custom objects: Neither the loss function nor the anchor box or L2-normalization layer types are contained in the Keras core library, so we need to provide them to the model loader.
#
# This next code cell assumes that you want to load a model that was created in 'training' mode. If you want to load a model that was created in 'inference' or 'inference_fast' mode, you'll have to add the DecodeDetections or DecodeDetectionsFast layer type to the custom_objects dictionary below.

# %%
# TODO: Set the path to the `.h5` file of the model to be loaded.
model_path = 'path/to/trained/model.h5'

# We need to create an SSDLoss object in order to pass that to the model loader.
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

K.clear_session() # Clear previous models from memory.

model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                               'L2Normalization': L2Normalization,
                                               'compute_loss': ssd_loss.compute_loss})

# %% [markdown]
# ## 3. Set up the data generators for the training

# %%
# data generation

# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.
# If you have enough memory, consider loading the images into memory
train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets. This can take a while.
# The directories that contain the images.
train_images_dir      = 'pascal voc/train/JPEGImages/'
val_images_dir      = 'pascal voc/val/JPEGImages/'

# The directories that contain the annotations.
train_annotations_dir      = 'pascal voc/train/Annotations/'
val_annotations_dir      = 'pascal voc/val/Annotations/'

# The directories that contain the imageset
train_image_set_filename = 'pascal voc/train/ImageSets/Main/trainval.txt'
val_image_set_filename   = 'pascal voc/val/ImageSets/Main/test.txt'

# The XML parser needs to now what object class names to look for and in which order to map them to integers.
classes = ['background',
           'aeroplane', 'bicycle', 'bird', 'boat',
           'bottle', 'bus', 'car', 'cat',
           'chair', 'cow', 'diningtable', 'dog',
           'horse', 'motorbike', 'person', 'pottedplant',
           'sheep', 'sofa', 'train', 'tvmonitor']

train_dataset.parse_xml(images_dirs=[train_images_dir],
                        image_set_filenames=[train_image_set_filename],
                        annotations_dirs=[train_annotations_dir],
                        classes=classes,
                        include_classes='all',
                        exclude_truncated=False,
                        exclude_difficult=False,
                        ret=False)

val_dataset.parse_xml(images_dirs=[val_images_dir],
                      image_set_filenames=[val_image_set_filename],
                      annotations_dirs=[val_annotations_dir],
                      classes=classes,
                      include_classes='all',
                      exclude_truncated=False,
                      exclude_difficult=True,
                      ret=False)

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

'''train_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07+12_trainval.h5',
                                  resize=False,
                                  variable_image_size=True,
                                  verbose=True)

val_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07_test.h5',
                                resize=False,
                                variable_image_size=True,
                                verbose=True)'''
# Out:
# Processing image set 'trainval.txt': 100%|████████████████████████████████████████| 5011/5011 [00:41<00:00, 120.82it/s]
# Loading images into memory: 100%|██████████████████████████████████████████████████| 5011/5011 [01:02<00:00, 80.50it/s]
# Processing image set 'test.txt': 100%|█████████████████████████████████████████████| 4952/4952 [00:58<00:00, 85.08it/s]
# Loading images into memory: 100%|██████████████████████████████████████████████████| 4952/4952 [02:19<00:00, 35.44it/s]
# "train_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07+12_trainval.h5',\n                                  resize=False,\n                                  variable_image_size=True,\n                                  verbose=True)\n\nval_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07_test.h5',\n                                resize=False,\n                                variable_image_size=True,\n                                verbose=True)"

# %%
# 3: Set the batch size.

batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  5011
# Number of images in the validation dataset:	  4952

# %% [markdown]
# ## 4. Set the remaining training parameters

# %%
# Define a learning rate schedule.

def lr_schedule(epoch):
    if epoch < 80:
        return 0.001
    elif epoch < 100:
        return 0.0001
    else:
        return 0.00001

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='ssd300_pascal_07_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)

csv_logger = CSVLogger(filename='ssd300_pascal_07_training_log.csv',
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan]

# %% [markdown]
# ## 5. Train

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 120
steps_per_epoch = ceil(train_dataset_size/batch_size)

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# W0609 16:39:59.846731  5992 module_wrapper.py:139] From C:\Users\abhinav.jhanwar\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0609 16:40:01.303448  5992 module_wrapper.py:139] From C:\Users\abhinav.jhanwar\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Epoch 1/120
